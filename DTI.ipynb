# %% [markdown]
# # Diffusion tensor imaging (DTI)
#
# The diffusion tensor model (Basser et al. 1994) has had huge influence and has propelled the use of dMRI.
#
# The model assumes that diffusion within each voxel can be described as a 3D Gaussian distribution. In this model, the diffusion signal in each voxel and direction is described through a slightly elaborated version of the Stejskal Tanner equation:
#
# $S(\theta, b) = S_0 \cdot e^{-b \theta Q \theta^t}$
#
# Where $\theta$ is a direction of measurement, sometimes also referred to as a 'b-vector', b is the b-value described in [signal formation](signal-formation.ipynb) and $Q$ is the diffusion tensor quadratic form, a set of variances and covariances:
#
# $ \left( \begin{array}{ccc}
# \sigma^2_x & \sigma_{xy} & \sigma_{xz} \\
# \sigma_{yx} & \sigma^2_{y} & \sigma_{yz} \\
# \sigma_{zx} & \sigma_{zy} & \sigma^2_{z} \end{array} \right) $
#
# This matrix is a rank 2 tensor, and because diffusion has antipodal symmetry, the covariances across the main diagonal are identical. For example: $\sigma_{xy} = sigma_{yx}$.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('presentation.mplstyle')

from mpl_toolkits.mplot3d import Axes3D
import IPython.html.widgets as wdg
import IPython.display as display

# %%
def dti_signal(theta, b, Q, S0=100):
    # We take the diagonal of this, because we are only interested in the multiplication of each vector with the 
    # matrix, not in various cross-products:
    adc = np.diag(np.dot(np.dot(theta, Q), theta.T))
    # ADC stands for 'apparent diffusion coefficient', which is an estimate of the diffusivity (in mm^2/s) 
    # in each direction of measurement. We will estimate that later with data
    return S0 * np.exp(-b * adc)

# %% [markdown]
# Let's start with an uninteresting case. Here, the diffusion is *isotropic*, meaning that it is identical in all directions:

# %%
Q = np.eye(3)
print(Q)
# Out:
# [[ 1.  0.  0.]
#  [ 0.  1.  0.]
#  [ 0.  0.  1.]]

# %%
theta = np.array([[1, 0, 0],  [0, 1, 0],  [0, 0, 1], [1/np.sqrt(2), 1/np.sqrt(2), 0]])
print(theta)
# Out:
# [[ 1.          0.          0.        ]
#  [ 0.          1.          0.        ]
#  [ 0.          0.          1.        ]
#  [ 0.70710678  0.70710678  0.        ]]

# %%
b = 2.0 # We need to scale b to the right units
dti_signal(theta, b, Q)
# Out:
# array([ 13.53352832,  13.53352832,  13.53352832,  13.53352832])

# %% [markdown]
# A slightly more interesting case, where diffusion is larger along the x axis than along the y,z axes:

# %%
Q = np.array([[1.5, 0, 0], [0, 0.5, 0], [0, 0, 0.5]])
print(Q)
# Out:
# [[ 1.5  0.   0. ]
#  [ 0.   0.5  0. ]
#  [ 0.   0.   0.5]]

# %%
dti_signal(theta, b, Q)
# Out:
# array([  4.97870684,  36.78794412,  36.78794412,  13.53352832])

# %% [markdown]
# As expected, the signal is lower for the 'measurement' along the x axis, than for 'measurements' along y or z. The 'measurement' that has a component along x and a component along y lies in between

# %% [markdown]
# Because of the antipodal symmetry, estimating the diffusion tensor amounts to fitting 6 independent parameters (3 variances and 3 covariances).
#
# One of the beautiful things about DTI is that the signal model can be linearized by taking the logarithm of both sides of the equation:

# %% [markdown]
# $S(\theta, b) = S_0 \cdot e^{-b \theta Q \theta^t}$
#
# $ \rightarrow log(\frac{S(\theta, b)}{S_0}) =  -b \cdot \theta Q \theta^t $
#
# $ \rightarrow y = X\beta$
#
# Where:
#
# $ y = log(\frac{S(\theta, b)}{S_0})$
#
# And:
#
# $X = -b \begin{pmatrix} \theta_{1x}^2 & \theta_{1y}^2 \theta_{1z}^2 & 2\theta_{1x1y} & 2\theta_{1x1z} & 2\theta_{1y1z} & 1 \\ \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
# \theta_{nx}^2 & \theta_{ny}^2 \theta_{nz}^2 & 2\theta_{nxny} & 2\theta_{nxnz} & 2\theta_{nynz} & 1
# \end{pmatrix} $
#
# $\beta = \begin{pmatrix} Q_{xx} \\  Q_{yy} \\ Q_{xy}\\ Q_{xz} \\ Q_{yz} \\ log(S_0) \end{pmatrix}$
#
# This allows us to solve for $\beta$ when we have at least 6 diffusion-weighted measurements in different directions.

# %% [markdown]
# We will use [`dipy`](http://dipy.org) to perform the fitting. We import a few modules which we will use:

# %%
import dipy.reconst.dti as dti 
import dipy.core.gradients as grad
import dipy.core.sphere as sph
import nibabel as nib

# %% [markdown]
# We simulate noise-free data. We will use the acquisition scheme from the data that you downloaded in the notebook about [dMRI signals](dMRI-signals.ipynb)

# %%
gtab = grad.gradient_table('data/stanford_hardi/HARDI150.bval', 'data/stanford_hardi/HARDI150.bvec')

# %%
sig1 = dti_signal(gtab.bvecs[~gtab.b0s_mask], b, Q)
plt.plot(sig1)

# %%
model = dti.TensorModel(gtab)
fit = model.fit(horiz_stack)

# %%
fit.evals
# Out:
# array([ 0.001,  0.001,  0.001])

# %%
prediction_gtab = grad.gradient_table(gtab.bvals[~gtab.b0s_mask], gtab.bvecs[~gtab.b0s_mask])

# %%
plt.scatter(fit.predict(prediction_gtab), sig1)

# %% [markdown]
# Let's grab some data:

# %%
vox_idx = (40, 74, 34)
data = nib.load('data/stanford_hardi/HARDI150.nii.gz').get_data()[vox_idx]

# %%
plt.plot(data)

# %%
fit = model.fit(data)

# %%
fit.evals
# Out:
# array([ 0.00143148,  0.00019157,  0.00015346])

# %%
fit.fa
# Out:
# 0.86713430206077702

# %%
data[10:]
# Out:
# array([228, 218,  46, 203, 106, 222, 130, 103, 225, 174, 199, 176,  99,
#         25,  81,  34, 185,  64,  21,  30,  74, 160, 174, 216,  35, 120,
#        176, 205, 151, 235,  79, 109,  65,  66,  58,  27,  80,  66, 162,
#         70, 190, 135, 215,  31, 277,  72,  55, 192,  43,  83,  79, 231,
#        154, 129, 134,  47,  20, 151, 138,  54, 108, 217, 181,  72, 114,
#         70,  47, 153, 113, 228, 166, 153,  57, 159,  40,  94,  90,  85,
#         46,  80,  25, 236, 192,  54,  47, 143,  87, 117,  58, 151, 179,
#        206, 114, 269, 181, 209,  54,  63,  11, 158, 139, 103, 209, 132,
#         90, 138,  22, 246, 120, 219,  16, 162, 189,  49,  94,  36, 160,
#        187, 177,  33,  58,  20,  85, 162,  70,  47,  34,  74, 105, 181,
#        118,  62,  23,  98,  41, 189,  35,  24,  59, 186,  73, 121,  75,
#         87,  41,  93, 131, 153, 183,  23], dtype=int16)

# %%
plt.scatter(fit.predict(prediction_gtab), data[10:])

# %%
plt.plot(fit.adc(sph.Sphere(xyz=prediction_gtab.bvecs)))

# %%
def color_from_val(val, min_val=0, max_val=255, cm=plt.cm.hot, n=256):
    val = np.asarray(val)
    seg = cm._segmentdata
    rgb = ['red', 'green', 'blue']
    lut = []
    for k in rgb:
        this_seg = np.array(seg[k])
        xp = this_seg[:,0]
        fp = this_seg[:,1]
        x = np.linspace(xp[0],xp[-1],n)

        lut.append(np.interp(x, xp, fp))
    
    lut = np.array(lut).T
    rgb = lut[(((float(val)-min_val)/(max_val-min_val))*(n-1)).astype(int)]        
    return tuple(rgb)


def plot_sig(azim=0, elev=0):
    x,y,z = prediction_gtab.bvecs.T
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(azim=azim, elev=elev)
    for idx, this_val in enumerate(val):
        c = color_from_val(this_val, min_val=np.min(val), max_val=np.max(val))
    
        # plot3D expects something with length, so we convert into 1-item arrays:
        ax.plot3D(np.ones(1) * x[idx], 
                      np.ones(1) * y[idx],
                      np.ones(1) * z[idx],
                      'o', c=c)
    return fig

# %%
ps_widget = wdg.interactive(plot_sig,
                            elev=wdg.FloatSliderWidget(min=-180, max=180, step=1.0, value=0),
                            azim=wdg.FloatSliderWidget(min=-180, max=180, step=1.0, value=0))

display.display(ps_widget)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-60c5a1afa1fc> in plot_sig(azim, elev)
#      22     ax = fig.add_subplot(111, projection='3d')
#      23     ax.view_init(azim=azim, elev=elev)
# ---> 24     for idx, this_val in enumerate(val):
#      25         c = color_from_val(this_val, min_val=np.min(val), max_val=np.max(val))
#      26
#
# NameError: global name 'val' is not defined
